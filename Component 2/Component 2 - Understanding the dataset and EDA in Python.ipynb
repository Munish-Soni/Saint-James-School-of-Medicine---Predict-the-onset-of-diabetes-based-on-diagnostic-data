# %% [markdown]
# ## Reading the data into a dataframe using Pandas

# %%
# As the data is in Comma Separated Values (csv) format
# we are going to use read_csv() function after importing it from pandas library

from pandas import read_csv

diabetes = read_csv ('diabetes.csv')

diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0              6      148             72             35        0  33.6  \
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Column Names

diabetes.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# ## Performing Basic Data Exploration

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.shape
# Out:
# (768, 9)

# %%
diabetes.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI
# 0             6      148             72             35        0  33.6  \
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin
# count   768.000000  768.000000     768.000000     768.000000  768.000000  \
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ## Applying Outlier Treatment

# %%
diabetes.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

plt.style.use('_mpl-gallery')

plt.figure(figsize=(10,4))

plt.boxplot(diabetes)

plt.xticks([1,2,3,4,5,6,7,8,9], ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'])

plt.show()

# %%
'''

After eye-balling the data, we can find that there are multiple zeroes in our dataset.

But, As we all know, no human being can have zero Blood Pressure, Skin Thickness, Insulin or BMI as long as they are alive.

So, for better functioning of our model, we need to perform Data Cleaning, Data Imputation & Outlier Treatment

'''
# Out:
# '\n\nAfter eye-balling the data, we can find that there are multiple zeroes in our dataset.\n\nBut, As we all know, no human being can have zero Blood Pressure, Skin Thickness, Insulin or BMI as long as they are alive.\n\nSo, for better functioning of our model, we need to perform Data Cleaning, Data Imputation & Outlier Treatment\n\n'

# %%
import seaborn as sns

# %%
sns.histplot(diabetes['BloodPressure'])
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Count'>

# %%
sns.histplot(diabetes['SkinThickness'])
# Out:
# <Axes: xlabel='SkinThickness', ylabel='Count'>

# %%
sns.histplot(diabetes['BMI'])
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %%
sns.histplot(diabetes['Insulin'])
# Out:
# <Axes: xlabel='Insulin', ylabel='Count'>

# %%
'''

After Inspection, we can see that there are relatively small number of missing values (zeros) in 'BMI' & 'BloodPressure' column.

Therefore, dropping the data with null values should be the best approach.

'''
# Out:
# "\n\nAfter Inspection, we can see that there are relatively small number of missing values (zeros) in 'BMI' & 'BloodPressure' column.\n\nTherefore, dropping the data with null values should be the best approach.\n\n"

# %%
# Creating a copy of the data, so the original data remains intact

diabetes_data = diabetes.copy()

# %%
# Removing missing values from BMI column

diabetes_data['BMI'].replace(0, None, inplace=True)
diabetes_data.dropna(axis=0, inplace=True)
diabetes_data['BMI'] = diabetes_data['BMI'].astype('int64')
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 757 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               757 non-null    int64
#  1   Glucose                   757 non-null    int64
#  2   BloodPressure             757 non-null    int64
#  3   SkinThickness             757 non-null    int64
#  4   Insulin                   757 non-null    int64
#  5   BMI                       757 non-null    int64
#  6   DiabetesPedigreeFunction  757 non-null    float64
#  7   Age                       757 non-null    int64
#  8   Outcome                   757 non-null    int64
# dtypes: float64(1), int64(8)
# memory usage: 59.1 KB

# %%
# Removing missing values from BloodPressure column

diabetes_data['BloodPressure'].replace(0, None, inplace=True)
diabetes_data.dropna(axis=0, inplace=True)
diabetes_data['BloodPressure'] = diabetes_data['BloodPressure'].astype('int64')
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 729 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               729 non-null    int64
#  1   Glucose                   729 non-null    int64
#  2   BloodPressure             729 non-null    int64
#  3   SkinThickness             729 non-null    int64
#  4   Insulin                   729 non-null    int64
#  5   BMI                       729 non-null    int64
#  6   DiabetesPedigreeFunction  729 non-null    float64
#  7   Age                       729 non-null    int64
#  8   Outcome                   729 non-null    int64
# dtypes: float64(1), int64(8)
# memory usage: 57.0 KB

# %%
# As we know, Data imputation is performed on Null values & not zeroes, so we replace zeros with Null values in SkinThickness and Insulin columns 

diabetes_data['SkinThickness'].replace(0, None, inplace=True)
diabetes_data['Insulin'].replace(0, None, inplace=True)

# %%
# Using IterativeImputer for imputation

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer()

imputer.fit (diabetes)

diabetes_data = imputer.transform (diabetes_data)

# %%
# Converting the output into a dataframe

from pandas import DataFrame
diabetes_data = DataFrame(diabetes_data, columns=diabetes.columns)
diabetes_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI
# 0            6.0    148.0           72.0      35.000000  143.275335  33.0  \
# 1            1.0     85.0           66.0      29.000000   69.166056  26.0
# 2            8.0    183.0           64.0      10.578094  125.142392  23.0
# 3            1.0     89.0           66.0      23.000000   94.000000  28.0
# 4            0.0    137.0           40.0      35.000000  168.000000  43.0
# ..           ...      ...            ...            ...         ...   ...
# 724         10.0    101.0           76.0      48.000000  180.000000  32.0
# 725          2.0    122.0           70.0      27.000000  104.327670  36.0
# 726          5.0    121.0           72.0      23.000000  112.000000  26.0
# 727          1.0    126.0           60.0      16.199531   70.289718  30.0
# 728          1.0     93.0           70.0      31.000000   87.088953  30.0
#
#      DiabetesPedigreeFunction   Age  Outcome
# ...

# %%
# Separating the predictor and Target Variables

X = diabetes_data.drop(columns=['Outcome'])
Y = diabetes_data['Outcome']

# %%
# We will be using IsolationForest Algorithm for Outlier detection on the entire dataset

from sklearn.ensemble import IsolationForest

If = IsolationForest()

diabetes_data['anomaly_score'] = If.fit_predict(X)

diabetes_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI
# 0            6.0    148.0           72.0      35.000000  143.275335  33.0  \
# 1            1.0     85.0           66.0      29.000000   69.166056  26.0
# 2            8.0    183.0           64.0      10.578094  125.142392  23.0
# 3            1.0     89.0           66.0      23.000000   94.000000  28.0
# 4            0.0    137.0           40.0      35.000000  168.000000  43.0
# ..           ...      ...            ...            ...         ...   ...
# 724         10.0    101.0           76.0      48.000000  180.000000  32.0
# 725          2.0    122.0           70.0      27.000000  104.327670  36.0
# 726          5.0    121.0           72.0      23.000000  112.000000  26.0
# 727          1.0    126.0           60.0      16.199531   70.289718  30.0
# 728          1.0     93.0           70.0      31.000000   87.088953  30.0
#
#      DiabetesPedigreeFunction   Age  Outcome  anomaly_score
# ...

# %%
# Total number of anomalies in the data

diabetes_data['anomaly_score'].value_counts()
# Out:
# anomaly_score
#  1    659
# -1     70
# Name: count, dtype: int64

# %%
# Percentage of anomalies in the data

70/659
# Out:
# 0.1062215477996965

# %%
# Now, since the anomalies are less than 20%, we will proceed with the Trimming approach on the data

diabetes_clean = diabetes_data[diabetes_data['anomaly_score'] == 1]

diabetes_clean.drop(columns = ['anomaly_score'], inplace=True)

diabetes_clean
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9228\1582742513.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diabetes_clean.drop(columns = ['anomaly_score'], inplace=True)
#      Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI
# 0            6.0    148.0           72.0      35.000000  143.275335  33.0  \
# 1            1.0     85.0           66.0      29.000000   69.166056  26.0
# 3            1.0     89.0           66.0      23.000000   94.000000  28.0
# 5            5.0    116.0           74.0      17.628134   67.834799  25.0
# 6            3.0     78.0           50.0      32.000000   88.000000  31.0
# ..           ...      ...            ...            ...         ...   ...
# 723          9.0     89.0           62.0      15.905015   26.688250  22.0
# ...

# %%
# Writing the clean data to an excel file

diabetes_clean.to_excel('diabetes_clean' + '.xlsx')
